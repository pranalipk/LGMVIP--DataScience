# %% [markdown]
# # LETS GROW MORE(VIP)
# # Batch: OCTOBER 2021
#
# ## Task 3:Exploratory Data Analysis on Dataset - Terrorism
#
# ### Author : Pranali Prakash Karande

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv(r'C:\Users\KARANDE SIR\Downloads\Global Terrorism - START data\globalterrorism.csv',encoding='ISO-8859-1', engine="python", error_bad_lines=False)

# %% [markdown]
# ## Basic Information

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### Terrorist activities by year

# %%
count =  df['iyear'].value_counts()
year = count.index.sort_values(ascending  = True)
val = []
for i in year:
    val.append(count[i])

# %%
plt.figure(figsize = (20,10))
plt.bar(year, val, tick_label = year, color = 'blue')
plt.xticks(rotation  = 90)
plt.title('Number of Terrorists Activities Per Year', fontsize=24)  
plt.xlabel('Year', fontsize = 18, labelpad = 30)
plt.ylabel('Number of terrorists attacks', fontsize = 18, labelpad = 30)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Terrorist Attacks By Region

# %%
pd.crosstab(df.iyear, df.region_txt).plot(kind='area',stacked=False,figsize=(15,6))
plt.title('Terrorist Activities By Region In Each Year',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xlabel("Year",fontsize=15)
plt.show()

# %% [markdown]
# ## Number of Attacks on Countries

# %%
plt.subplots(figsize=(8,10))
sns.barplot(df['country_txt'].value_counts()[:16].values,df['country_txt'].value_counts()[:16].index,palette='Paired')
plt.title('Number of Attacks on Countries')
plt.ylabel('Countries')
plt.xlabel('range')
plt.xticks(rotation= 0)
plt.show()

# %% [markdown]
# ### Types of Attacks

# %%
attack_type = df.attacktype1_txt.value_counts()[:15]
attack_type
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
plt.subplots(figsize=(12,6))
sns.barplot(attack_type.index,attack_type.values,palette="rocket")
plt.title('Attack Types')
plt.xlabel('Types ot attacks')
plt.ylabel('Number of attacks')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ## Most attacked country

# %%
print("Most Attacked Country:",df["country_txt"].value_counts().idxmax())
# Out:
# Most Attacked Country: Iraq

# %% [markdown]
# ## Number of people killed by terror attack

# %%
killedpeople = df.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(killedpeople.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# ## Gang with most number of attacks

# %%
print("Gang with most number of attacks:",df['gname'].value_counts().index[1])
# Out:
# Gang with most number of attacks: Taliban

# %% [markdown]
# ## Most frequently used attack type

# %%
print("Most frequently used attack type:",df['attacktype1_txt'].value_counts().idxmax())
# Out:
# Most frequently used attack type: Bombing/Explosion

# %% [markdown]
# # Conclusion
# #### The peak in terms of Number of Terrorists Attacks was observed in 2014.
#
# #### The country which is most affected by terrorist attacks is Iraq.
#
# #### The Most Used Attack Type by Terrorists is Bombing/Explosion.
#
# #### The Group with most attacks is Taliban
